# %%
# Dependencies
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
# Save file path to variable
data = "part2data.csv"

# %%
# Read with Pandas
data_pd = pd.read_csv(data)
data_pd.head()
# Out:
#   Country Name                         Series Name 2014 [YR2014]  \
# 0       Brazil               GDP growth (annual %)    0.50395574
# 1       Brazil                   GDP (current US$)   2.45599E+12
# 2       Brazil                   GNI (current US$)   2.40738E+12
# 3       Brazil  GNI per capita (constant 2010 US$)     11713.099
# 4       Brazil    GDP per capita growth (annual %)  -0.352479218
#
#   2015 [YR2015] 2016 [YR2016] 2017 [YR2017] 2018 [YR2018]
# 0  -3.545763393  -3.305454313   1.063861259    1.11757918
# 1   1.80221E+12   1.79628E+12   2.05359E+12   1.86863E+12
# 2   1.76331E+12   1.75881E+12   2.01553E+12    1.8402E+12
# 3   11183.30902   10732.88221   10785.84543   10857.43411
# 4  -4.351483989  -4.098702255   0.251410419   0.328069801

# %%
data_pd = data_pd.rename(columns={'2014 [YR2014]':'2014','2015 [YR2015]':'2015','2016 [YR2016]':'2016','2017 [YR2017]':'2017','2018 [YR2018]':'2018'})
data_pd.head()
# Out:
#   Country Name                         Series Name          2014  \
# 0       Brazil               GDP growth (annual %)    0.50395574
# 1       Brazil                   GDP (current US$)   2.45599E+12
# 2       Brazil                   GNI (current US$)   2.40738E+12
# 3       Brazil  GNI per capita (constant 2010 US$)     11713.099
# 4       Brazil    GDP per capita growth (annual %)  -0.352479218
#
#            2015          2016         2017         2018
# 0  -3.545763393  -3.305454313  1.063861259   1.11757918
# 1   1.80221E+12   1.79628E+12  2.05359E+12  1.86863E+12
# 2   1.76331E+12   1.75881E+12  2.01553E+12   1.8402E+12
# 3   11183.30902   10732.88221  10785.84543  10857.43411
# 4  -4.351483989  -4.098702255  0.251410419  0.328069801

# %%
completedf = data_pd
completedf.head()
# Out:
#   Country Name                         Series Name          2014  \
# 0       Brazil               GDP growth (annual %)    0.50395574
# 1       Brazil                   GDP (current US$)   2.45599E+12
# 2       Brazil                   GNI (current US$)   2.40738E+12
# 3       Brazil  GNI per capita (constant 2010 US$)     11713.099
# 4       Brazil    GDP per capita growth (annual %)  -0.352479218
#
#            2015          2016         2017         2018
# 0  -3.545763393  -3.305454313  1.063861259   1.11757918
# 1   1.80221E+12   1.79628E+12  2.05359E+12  1.86863E+12
# 2   1.76331E+12   1.75881E+12  2.01553E+12   1.8402E+12
# 3   11183.30902   10732.88221  10785.84543  10857.43411
# 4  -4.351483989  -4.098702255  0.251410419  0.328069801

# %%
brazildf = completedf
brazildf.drop(brazildf.index[brazildf['Country Name'] != 'Brazil'], inplace = True)
brazildf
# Out:
#    Country Name                                        Series Name  \
# 0        Brazil                              GDP growth (annual %)
# 1        Brazil                                  GDP (current US$)
# 2        Brazil                                  GNI (current US$)
# 3        Brazil                 GNI per capita (constant 2010 US$)
# 4        Brazil                   GDP per capita growth (annual %)
# 5        Brazil                       GDP per capita (current US$)
# 6        Brazil                 Inflation, GDP deflator (annual %)
# 7        Brazil  Unemployment with advanced education (% of tot...
# 8        Brazil  Unemployment with basic education (% of total ...
# 9        Brazil  Unemployment with intermediate education (% of...
# 10       Brazil  Unemployment, total (% of total labor force) (...
# 11       Brazil  Unemployment, total (% of total labor force) (...
#
#             2014          2015          2016         2017         2018
# ...

# %%
worlddf = completedf
worlddf.drop(worlddf.index[worlddf['Country Name'] != 'World'], inplace = True)
worlddf
# Out:
#    Country Name                                        Series Name  \
# 12        World                              GDP growth (annual %)
# 13        World                                  GDP (current US$)
# 14        World                                  GNI (current US$)
# 15        World                 GNI per capita (constant 2010 US$)
# 16        World                   GDP per capita growth (annual %)
# 17        World                       GDP per capita (current US$)
# 18        World                 Inflation, GDP deflator (annual %)
# 19        World  Unemployment with advanced education (% of tot...
# 20        World  Unemployment with basic education (% of total ...
# 21        World  Unemployment with intermediate education (% of...
# 22        World  Unemployment, total (% of total labor force) (...
# 23        World  Unemployment, total (% of total labor force) (...
#
#            2014         2015         2016         2017         2018
# ...

# %%
usdf = completedf
usdf.drop(usdf.index[usdf['Country Name'] != 'World'], inplace = True)
usdf
# Out:
#    Country Name                                        Series Name  \
# 12        World                              GDP growth (annual %)
# 13        World                                  GDP (current US$)
# 14        World                                  GNI (current US$)
# 15        World                 GNI per capita (constant 2010 US$)
# 16        World                   GDP per capita growth (annual %)
# 17        World                       GDP per capita (current US$)
# 18        World                 Inflation, GDP deflator (annual %)
# 19        World  Unemployment with advanced education (% of tot...
# 20        World  Unemployment with basic education (% of total ...
# 21        World  Unemployment with intermediate education (% of...
# 22        World  Unemployment, total (% of total labor force) (...
# 23        World  Unemployment, total (% of total labor force) (...
#
#            2014         2015         2016         2017         2018
# ...

# %%
completedf
# Out:
#    Country Name                                        Series Name  \
# 12        World                              GDP growth (annual %)
# 13        World                                  GDP (current US$)
# 14        World                                  GNI (current US$)
# 15        World                 GNI per capita (constant 2010 US$)
# 16        World                   GDP per capita growth (annual %)
# 17        World                       GDP per capita (current US$)
# 18        World                 Inflation, GDP deflator (annual %)
# 19        World  Unemployment with advanced education (% of tot...
# 20        World  Unemployment with basic education (% of total ...
# 21        World  Unemployment with intermediate education (% of...
# 22        World  Unemployment, total (% of total labor force) (...
# 23        World  Unemployment, total (% of total labor force) (...
#
#            2014         2015         2016         2017         2018
# ...
